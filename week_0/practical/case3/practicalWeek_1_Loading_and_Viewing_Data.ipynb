# %% [markdown]
# # Overview - Welcome to week 1 practical (coding part)

# %% [markdown]
# This Week 1 notebook provides an introduction to the fundamentals of Python programming, basic Markdown syntax for writing clear notes, and essential data manipulation skills using pandas.

# %% [markdown]
# ## 🐍 Python Libraries We'll Use
#
# - **[pandas](https://pypi.org/project/pandas/)** - a Python package that provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive.

# %% [markdown]
# # 🔧 Introduction to Jupyter/Colab notebooks

# %% [markdown]
# Python is the programming language used in this course. There are two common file formats for writing Python-related work:
#
# - **`.py` files** – standard Python script files that contain only code and are typically edited in environments (editors) such as [VS Code](https://code.visualstudio.com/) or [PyCharm](https://www.jetbrains.com/pycharm/).
# - **`.ipynb` files** – Jupyter Notebook files that combine **code, text explanations, and outputs** in an interactive document, making them especially suitable for data analysis and teaching.
#
# Both `.py` and `.ipynb` ultimately run **Python code**, but notebooks provide a more interactive and visual workflow, which is why they are widely used in Data Science.
#
# [Jupyter Notebook](https://jupyter.org/) and [Google Colab](https://colab.google/) are interactive environments widely used in Data Science. They allow you to write **code**, **text explanations**, and **visualisations** in a single document.
#
# A notebook is organised into **cells**, which can be:
#
# - **Code cells** – used to run Python code and display outputs.
# - **Markdown cells** – used to write notes, explanations, headings, or formatted text.

# %%
print('This is a Code cell. Run this cell to print the output')
# Out:
# This is a Code cell. Run this cell to print the output

# %% [markdown]
# This is a Markdown cell.

# %% [markdown]
# To run a code cell:
#
# - Press **Shift + Enter** to execute the cell and move to the next one.
# - Outputs (numbers, tables, plots, errors) appear directly below the cell.
#
# Google Colab is a cloud-based version of Jupyter:
#
# - No installation is required.
# - Files are saved to **Google Drive**.
# - Free access to **CPU, GPU, and RAM** resources.

# %% [markdown]
# We do not restrict which editor you use. You may choose **Google Colab, VS Code, or any other editor** you prefer. However, **Colab is recommended** because it works out of the box and is not limited by your local machine, operating system, or environment setup.

# %% [markdown]
# ## A question for you
# 🤔️ Why is it useful to combine **code, text explanations, and visualisations** in a single notebook for data science work?

# %% [markdown]
# 'Your answer here ...'

# %% [markdown]
# # Markdown for notes and explanations

# %% [markdown]
# Before we start working with data, it is important to learn how to write clear **notes and explanations** inside a notebook.
#
# It allows you to document your **thinking process**, not just your code — which is an essential skill in Data Science.
#
# In this section, you will learn the basic Markdown syntax needed for this course and practise writing short formatted notes inside a notebook.

# %% [markdown]
# ## Headings
# To create a heading, add number signs (#) in front of a word or phrase. The number of number signs you use should correspond to the heading level.

# %% [markdown]
# ### Your turn: Create a level three heading called Data Science

# %% [markdown]
# ## Emphasis - Bold
# To **bold text**, add two asterisks or underscores before and after a word or phrase. To bold the middle of a word for emphasis, add two asterisks without spaces around the letters.

# %% [markdown]
# ### Your turn: Bold the text "multidisciplinary" below.

# %% [markdown]
# Data science is often described as a multidisciplinary and rapidly evolving field because it draws on techniques from diverse areas, such as computer science, statistics, information science, and other subject-specific disciplines.

# %% [markdown]
# ## Emphasis - Italic
# To *italicize text*, add one asterisk or underscore before and after a word or phrase. To italicize the middle of a word for emphasis, add one asterisk without spaces around the letters.

# %% [markdown]
# ### Your turn: Italicize the text "programming code" below.

# %% [markdown]
# A data scientist is a professional who creates programming code and combines it with statistical knowledge to summarize data.

# %% [markdown]
# ## Ordered Lists
# To create an ordered list, add line items with numbers followed by periods. The numbers don’t have to be in numerical order, but the list should start with the number one.

# %% [markdown]
# ### Your turn: Create an Ordered List of numbers '10', '100', '1000', and '10000' in ascending order.

# %% [markdown]
# ## 📚 What's more
# Here is a comprehensive Markdown [syntax guide](https://www.markdownguide.org/basic-syntax/). You can explore it after class to learn and practise more advanced features, such as inserting hyperlinks, images, and other formatting operations.

# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# [Pandas](https://pandas.pydata.org) is a Python module that provides some important data structures for Data Science work and a large collection of methods for data analysis.
#
# The two main data structures are the [Series]() and [DataFrame](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe).
#
# A Series is a one dimensional array of data, but unlike the Python list the data is indexed - the index is like the dictionary key, any immutable value like a number or string.  You can use the label to select elements from the series as well as positional values.
#
# A DataFrame is analogous to a spreadsheet - a two dimensional table of data with indexed rows and named columns.

# %%
# Before using it, you should import it first
import pandas as pd
# If you encounter an error such as a missing xxx library,
# it indicates that you should try installing the package locally.
# You can use the following command:
# !pip install pandas

# %% [markdown]
# Download the three datasets (ds1, ds2 and ds3) from iLearn and upload them to Colab.
# If you are running Jupyter Notebook locally, uploading is not required.
# You may also need to modify the file paths shown below.

# %%
ds1 = 'ds1.csv'
ds2 = 'ds2.csv'
ds3 = 'ds3.csv'

# %% [markdown]
# ## Loading data with pandas.read_csv()

# %%
# Reading two csv files as dataframes using read_csv function
df1 = pd.read_csv(ds1)
df2 = pd.read_csv(ds2)

# %% [markdown]
# ## Viewing data

# %%
# Displaying first few rows of the dataframe df1
print(df1.head())

# %%
# Displaying first 10 rows of the dataframe df1
print(df1.head(10))

# %%
# Displaying last few rows of the dataframe df2
print(df1.tail())

# %%
# Checkout the shape of dataframe - df1
print(df1.shape)

# %%
# print out the number of rows and columns of df2
print(f'There are {df2.shape[0]} rows and {df2.shape[1]} columns in df2.')

# %%
# Describing summary statistics of a dataframe
print(df2.describe())

# %% [markdown]
# ## Practice
#
# Now is your turn to checkout the df3.

# %%
# Reading ds3 as dataframe using read_csv function

# %%
# Displaying first few rows of the dataframe df3

# %%
# Displaying last 15 rows of the dataframe df3

# %%
# print out the number of rows and columns of df3

# %%
# Describing summary statistics of dataframe df3

# %% [markdown]
# # Further Practice [Optional]
# If you have completed the tasks above, you may try the following more challenging activities.
# Completion of this section will not affect your grade.

# %% [markdown]
# Use Markdown syntax to recreate the content displayed in the image. The links in the text on the words 'Markdown' and 'Markdown-formatted' should go to https://daringfireball.net/projects/markdown/ and the image can be found at https://git-scm.com/images/logos/downloads/Git-Logo-2Color.png.
#
#
#
# ![image.png](data:image/png;base64,...)
